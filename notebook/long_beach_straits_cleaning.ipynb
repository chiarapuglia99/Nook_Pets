# %% [markdown]
# # Importo le librerie necessarie

# %%
import pandas as pd

# %% [markdown]
# # Controllo la locazione del dataset per verificarne la correttezza

# %%
df = pd.read_csv("../dataset/strade_long_beach.csv", encoding='latin-1')

# (Opzionale) Visualizza le informazioni iniziali per vedere quanti null ci sono
print("Info dataset originale:")
print(df.info())
# Out:
# Info dataset originale:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21061 entries, 0 to 21060
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fid       21061 non-null  int64
#  1   osm_id    21061 non-null  int64
#  2   code      21061 non-null  int64
#  3   fclass    21061 non-null  object
#  4   name      9499 non-null   object
#  5   ref       820 non-null    object
#  6   oneway    21061 non-null  object
#  7   maxspeed  21061 non-null  int64
#  8   layer     21061 non-null  int64
#  9   bridge    21061 non-null  object
#  10  tunnel    21061 non-null  object
# dtypes: int64(5), object(6)
# memory usage: 1.8+ MB
# None

# %% [markdown]
# # Eliminazione delle strade che presentano il valore del campo "name" uguale a null
#
# Effettuo questa modifica poichè su qgis, è stata effettuata una categorizzazione delle strade e sono state eliminate alcune strade poichè non erano fondamentali ai fini della nostra analisi

# %%
# 2. Eliminazione delle righe con valore 'name' nullo
df_cleaned = df.dropna(subset=['name'])

# %% [markdown]
# # Verifica ulteriore per assicurarsi che la pulizia sia stata effettuata correttamente

# %%
print("\nInfo dataset pulito:")
print(df_cleaned.info())
# Out:
# Info dataset pulito:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9499 entries, 3 to 21058
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fid       9499 non-null   int64
#  1   osm_id    9499 non-null   int64
#  2   code      9499 non-null   int64
#  3   fclass    9499 non-null   object
#  4   name      9499 non-null   object
#  5   ref       797 non-null    object
#  6   oneway    9499 non-null   object
#  7   maxspeed  9499 non-null   int64
#  8   layer     9499 non-null   int64
#  9   bridge    9499 non-null   object
#  10  tunnel    9499 non-null   object
# dtypes: int64(5), object(6)
# memory usage: 890.5+ KB
# None

# %% [markdown]
# # Salvataggio del dataset pulito in un nuovo file CSV

# %%
output_filename = '../dataset/strade_long_beach_cleaned.csv'
df_cleaned.to_csv(output_filename, index=False)

print(f"\nFile salvato come: {output_filename}")
# Out:
# File salvato come: ../dataset/strade_long_beach_cleaned.csv

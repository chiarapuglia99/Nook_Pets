# %% [markdown]
# # Importo le librerie necessarie

# %%
import pandas as pd

# %% [markdown]
# # Controllo la locazione del dataset per verificarne la correttezza

# %%
df = pd.read_csv("../dataset/strade_los_angeles.csv", encoding='latin-1')

# (Opzionale) Visualizza le informazioni iniziali per vedere quanti null ci sono
print("Info dataset originale:")
print(df.info())
# Out:
# Info dataset originale:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167484 entries, 0 to 167483
# Data columns (total 11 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   fid       167484 non-null  int64
#  1   osm_id    167484 non-null  int64
#  2   code      167484 non-null  int64
#  3   fclass    167484 non-null  object
#  4   name      61351 non-null   object
#  5   ref       3674 non-null    object
#  6   oneway    167484 non-null  object
#  7   maxspeed  167484 non-null  int64
#  8   layer     167484 non-null  int64
#  9   bridge    167484 non-null  object
#  10  tunnel    167484 non-null  object
# dtypes: int64(5), object(6)
# memory usage: 14.1+ MB
# None

# %% [markdown]
# # Eliminazione delle strade che presentano il valore del campo "name" uguale a null
#
# Effettuo questa modifica poichè su qgis, è stata effettuata una categorizzazione delle strade e sono state eliminate alcune strade poichè non erano fondamentali ai fini della nostra analisi

# %%
# 2. Eliminazione delle righe con valore 'name' nullo
df_cleaned = df.dropna(subset=['name'])

# %% [markdown]
# # Verifica ulteriore per assicurarsi che la pulizia sia stata effettuata correttamente

# %%
print("\nInfo dataset pulito:")
print(df_cleaned.info())
# Out:
# Info dataset pulito:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61351 entries, 0 to 167474
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fid       61351 non-null  int64
#  1   osm_id    61351 non-null  int64
#  2   code      61351 non-null  int64
#  3   fclass    61351 non-null  object
#  4   name      61351 non-null  object
#  5   ref       3581 non-null   object
#  6   oneway    61351 non-null  object
#  7   maxspeed  61351 non-null  int64
#  8   layer     61351 non-null  int64
#  9   bridge    61351 non-null  object
#  10  tunnel    61351 non-null  object
# dtypes: int64(5), object(6)
# memory usage: 5.6+ MB
# None

# %% [markdown]
# # Salvataggio del dataset pulito in un nuovo file CSV

# %%
output_filename = '../dataset/strade_los_angeles_cleaned.csv'
df_cleaned.to_csv(output_filename, index=False)

print(f"\nFile salvato come: {output_filename}")
# Out:
# File salvato come: ../dataset/strade_los_angeles_pulito.csv
